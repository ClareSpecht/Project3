# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
import lxml.html as lh
import re

from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite://', echo=False)

# %%
states= pd.read_csv('states.csv')
# states=states.rename(columns={"State.1": "StateAbv"})\
#     .drop(columns=['State Capital','Region'])\
#     .reset_index(drop=True)
# Just to be sure no spaces remain in column for merge!!! 
states['State.1'] = states['State.1'].str.strip()
# states.convert_dtypes()
states.head()
# Out:
#         State State.1 State Capital Region
# 0     Alabama      AL    Montgomery  South
# 1      Alaska      AK        Juneau   West
# 2     Arizona      AZ       Phoenix   West
# 3    Arkansas      AR   Little Rock  South
# 4  California      CA    Sacramento   West

# %%
state =states["State.1"]
nat_park=[]  #This is where it all winds up

for name in state:
    st_park = [] # will be a list for list for all st parks- resets on each loop
    
    url=f'https://stateparks.com/{name}.html'
    response = requests.get(url)
    soup = bs(response.text, 'html.parser')
    results= soup.find('div', id="overview")
    body = results.find_all('div', style="display:inline-block;")
    
    for row_num in range(len(body)): 
        row = [] # this will hold entries for one row- resets each loop
        for row_item in body[row_num]:
            aa = re.sub("(\xa0)|(\n)|,|•| "," ",row_item.text)
            if len(row) >1:
                del row[0]    
            row.append(aa)
        st_park.append(row)
  
    nat_park.append(st_park)

# %%
st_park
# Out:
# [['', 'National Memorial'], ['2', ' National Historic Sites']]

# %%
df=pd.DataFrame(nat_park)
df
# Out:
#                        0                                       1   \
# 0      [24,  State Parks]                     [3,  State Forests]
# 1       [4,  State Parks]                    [2,  National Parks]
# 2      [16,  State Parks]               [, State Recreation Area]
# 3      [36,  State Parks]                        [, State Forest]
# 4     [109,  State Parks]            [9,  State Recreation Areas]
# 5       [6,  State Parks]                     [2,  State Forests]
# 6      [53,  State Parks]                    [25,  State Forests]
# 7      [15,  State Parks]                     [2,  State Forests]
# 8     [114,  State Parks]                     [5,  State Forests]
# 9      [53,  State Parks]                        [, State Forest]
# 10     [10,  State Parks]                    [2,  National Parks]
# 11     [23,  State Parks]                        [, State Forest]
# 12     [69,  State Parks]           [11,  State Recreation Areas]
# 13     [26,  State Parks]                    [15,  State Forests]
# 14     [63,  State Parks]                     [5,  State Forests]
# 15     [31,  State Parks]             [32,  State Wildlife Areas]
# 16     [38,  State Parks]                     [3,  State Forests]
# 17     [20,  State Parks]                        [, State Forest]
# 18     [34,  State Parks]                       [, National Park]
# 19     [37,  State Parks]                     [5,  State Forests]
# 20     [24,  State Parks]                    [38,  State Forests]
# 21     [74,  State Parks]                    [12,  State Forests]
# 22     [52,  State Parks]                    [11,  State Forests]
# 23     [23,  State Parks]              [2,  State Wildlife Areas]
# 24     [38,  State Parks]                     [7,  State Forests]
# 25     [38,  State Parks]      [, State Wildlife Management Area]
# 26      [9,  State Parks]  [11,  State Wildlife Management Areas]
# 27     [20,  State Parks]               [, State Recreation Area]
# 28     [20,  State Parks]                     [5,  State Forests]
# 29     [34,  State Parks]                    [11,  State Forests]
# 30     [28,  State Parks]                 [, State Fish Hatchery]
# 31     [89,  State Parks]                     [3,  State Forests]
# 32     [35,  State Parks]               [, State Recreation Area]
# 33      [7,  State Parks]                 [, State Historic Site]
# 34     [77,  State Parks]                    [17,  State Forests]
# 35     [35,  State Parks]              [3,  State Fish Hatcherys]
# 36    [111,  State Parks]                     [3,  State Forests]
# 37    [111,  State Parks]                    [19,  State Forests]
# 38      [9,  State Parks]                       [, National Park]
# 39     [40,  State Parks]                     [4,  State Forests]
# 40     [15,  State Parks]                    [2,  National Parks]
# 41     [31,  State Parks]                    [10,  State Forests]
# 42     [76,  State Parks]                     [2,  State Forests]
# 43     [29,  State Parks]                       [, State Reserve]
# 44     [12,  State Parks]                     [7,  State Forests]
# 45     [24,  State Parks]                     [5,  State Forests]
# 46    [131,  State Parks]            [6,  State Recreation Areas]
# 47     [29,  State Parks]                     [9,  State Forests]
# 48     [42,  State Parks]                     [8,  State Forests]
# 49     [13,  State Parks]                    [2,  National Parks]
# 50  [, National Memorial]           [2,  National Historic Sites]
#
#                                        2   \
# 0   [4,  State Wildlife Management Areas]
# 1                  [2,  National Forests]
# 2                 [, State Historic Site]
# 3                 [, State Historic Site]
# 4                     [6,  State Forests]
# 5                 [, State Fish Hatchery]
# 6              [2,  State Wildlife Areas]
# 7                 [, State Wildlife Area]
# 8                      [, State Memorial]
# 9                      [, State Memorial]
# 10                  [, National Memorial]
# 11             [2,  State Fish Hatcherys]
# 12                    [6,  State Forests]
# 13                  [4,  State Memorials]
# 14             [3,  State Wildlife Areas]
# 15  [3,  State Wildlife Management Areas]
# 16            [12,  State Historic Sites]
# 17             [2,  State Historic Sites]
# 18        [8,  National Wildlife Refuges]
# 19  [6,  State Wildlife Management Areas]
# 20     [, State Wildlife Management Area]
# 21                      [, State Reserve]
# 22  [9,  State Wildlife Management Areas]
# 23  [8,  State Wildlife Management Areas]
# 24             [7,  State Historic Sites]
# 25                   [2,  National Parks]
# 26                 [2,  National Forests]
# 27                [, State Fish Hatchery]
# 28                      [, National Park]
# 29                      [, State Airport]
# 30                   [3,  National Parks]
# 31                [, State Wildlife Area]
# 32                    [2,  State Forests]
# 33                  [, National Memorial]
# 34                 [20,  State Memorials]
# 35  [2,  State Wildlife Management Areas]
# 36             [6,  State Fish Hatcherys]
# 37                      [, National Park]
# 38                  [, National Memorial]
# 39                [, State Historic Site]
# 40                    [, National Forest]
# 41              [3,  State Scenic Rivers]
# 42             [2,  State Historic Sites]
# 43                   [5,  National Parks]
# 44                    [, National Forest]
# 45             [2,  State Fish Hatcherys]
# 46                    [2,  State Forests]
# 47                [, State Fish Hatchery]
# 48              [3,  State Fishery Areas]
# 49                 [5,  National Forests]
# 50                                   None
#
#                                        3   \
# 0                       [, National Park]
# 1           [2,  National Historic Parks]
# 2                 [, State Fish Hatchery]
# 3              [2,  State Fish Hatcherys]
# 4              [5,  State Historic Sites]
# 5              [5,  State Wildlife Areas]
# 6                [, Metro and City Parks]
# 7   [3,  State Wildlife Management Areas]
# 8             [17,  State Historic Sites]
# 9             [15,  State Historic Sites]
# 10          [2,  National Historic Parks]
# 11                      [, National Park]
# 12                  [2,  State Memorials]
# 13                [, State Historic Site]
# 14  [7,  State Wildlife Management Areas]
# 15                      [, National Park]
# 16                      [, National Park]
# 17  [9,  State Wildlife Management Areas]
# 18                                   None
# 19                   [4,  National Parks]
# 20                      [, National Park]
# 21                [, State Wildlife Area]
# 22                      [, National Park]
# 23                 [6,  National Forests]
# 24                 [, State Natural Area]
# 25                [10,  National Forests]
# 26             [, National Historic Site]
# 27  [3,  State Wildlife Management Areas]
# 28                    [, National Forest]
# 29     [, State Wildlife Management Area]
# 30                 [5,  National Forests]
# 31     [, State Wildlife Management Area]
# 32                [, State Fish Hatchery]
# 33          [2,  National Historic Sites]
# 34           [4,  State Nature Preserves]
# 35          [2,  National Historic Sites]
# 36                 [, State Natural Area]
# 37                    [, National Forest]
# 38             [, National Historic Site]
# 39                     [, State Preserve]
# 40                  [, National Memorial]
# 41              [3,  State Natural Areas]
# 42                [, State Fish Hatchery]
# 43                 [4,  National Forests]
# 44           [, National Wildlife Refuge]
# 45  [2,  State Wildlife Management Areas]
# 46                 [, State Natural Area]
# 47                      [, National Park]
# 48                [, State Fish Hatchery]
# 49          [2,  National Historic Sites]
# 50                                   None
#
#                                        4   \
# 0                  [4,  National Forests]
# 1                [2,  National Monuments]
# 2                 [, State Wildlife Area]
# 3                  [, State Natural Area]
# 4              [5,  State Fish Hatcherys]
# 5                    [3,  National Parks]
# 6                                    None
# 7         [2,  National Wildlife Refuges]
# 8                    [3,  State Reserves]
# 9               [, State Nature Preserve]
# 10                                   None
# 11                [10,  National Forests]
# 12              [, State Nature Preserve]
# 13                 [, State Fishing Area]
# 14             [, National Historic Site]
# 15          [4,  National Historic Sites]
# 16                    [, National Forest]
# 17              [, State Wildlife Refuge]
# 18                                   None
# 19             [, National Historic Site]
# 20          [6,  National Historic Sites]
# 21     [, State Wildlife Management Area]
# 22                 [2,  National Forests]
# 23             [, National Historic Site]
# 24            [12,  State Wildlife Areas]
# 25          [2,  National Historic Sites]
# 26               [2,  National Monuments]
# 27                      [, National Park]
# 28           [, National Wildlife Refuge]
# 29                   [2,  National Parks]
# 30      [3,  National Historic Landmarks]
# 31                      [, National Park]
# 32                   [2,  National Parks]
# 33       [16,  National Wildlife Refuges]
# 34                   [2,  State Reserves]
# 35             [, National Wildlife Area]
# 36                      [, State Nursery]
# 37               [2,  National Memorials]
# 38        [4,  National Wildlife Refuges]
# 39                   [2,  National Parks]
# 40             [, National Historic Site]
# 41  [3,  State Wildlife Management Areas]
# 42              [2,  State Natural Areas]
# 43          [2,  National Historic Sites]
# 44           [, National Recreation Area]
# 45                   [7,  National Parks]
# 46                [, State Wildlife Area]
# 47                    [, National Forest]
# 48                              [, Trail]
# 49        [4,  National Wildlife Refuges]
# 50                                   None
#
#                                         5   \
# 0            [2,  National Historic Sites]
# 1         [22,  National Wildlife Refuges]
# 2                     [4,  National Parks]
# 3   [12,  State Wildlife Management Areas]
# 4                [, State Nature Preserve]
# 5                  [11,  National Forests]
# 6                                     None
# 7                                     None
# 8                   [19,  State Preserves]
# 9       [, State Wildlife Management Area]
# 10                                    None
# 11              [, National Historic Site]
# 12               [5,  State Natural Areas]
# 13                 [, State Fish Hatchery]
# 14                   [, National Monument]
# 15         [3,  National Wildlife Refuges]
# 16           [2,  National Historic Parks]
# 17                    [2,  National Parks]
# 18                                    None
# 19              [, National Historic Park]
# 20           [3,  National Historic Parks]
# 21                    [2,  National Parks]
# 22         [6,  National Wildlife Refuges]
# 23         [9,  National Wildlife Refuges]
# 24   [6,  State Wildlife Management Areas]
# 25                   [, National Monument]
# 26         [6,  National Wildlife Refuges]
# 27                  [7,  National Forests]
# 28                                    None
# 29              [, National Historic Site]
# 30              [, National Historic Site]
# 31           [5,  National Historic Sites]
# 32                  [4,  National Forests]
# 33                                    None
# 34             [14,  State Wildlife Areas]
# 35         [4,  National Wildlife Refuges]
# 36                       [, National Park]
# 37           [5,  National Historic Sites]
# 38                                    None
# 39                     [, National Forest]
# 40                   [, National Monument]
# 41                       [, National Park]
# 42                    [3,  National Parks]
# 43                [4,  National Monuments]
# 44                                    None
# 45                  [2,  National Forests]
# 46                    [3,  National Parks]
# 47              [, National Historic Park]
# 48              [7,  State Wildlife Areas]
# 49         [2,  National Recreation Areas]
# 50                                    None
#
#                                        6                                   7   \
# 0              [, National Historic Park]            [2,  National Monuments]
# 1           [, National Recreation Trail]   [7,  National Park and Preserves]
# 2                  [8,  National Forests]               [, National Memorial]
# 3                       [, National Park]              [3,  National Forests]
# 4                   [10,  State Reserves]         [10,  State Wildlife Areas]
# 5          [, National Historic Landmark]               [, National Monument]
# 6                                    None                                None
# 7                                    None                                None
# 8                    [3,  National Parks]              [3,  National Forests]
# 9               [, State Wildlife Refuge]              [2,  National Forests]
# 10                                   None                                None
# 11             [, National Historic Park]               [, National Monument]
# 12            [17,  State Wildlife Areas]  [, State Wildlife Management Area]
# 13              [, State Nature Preserve]         [13,  State Wildlife Areas]
# 14        [3,  National Wildlife Refuges]            [, Metro and City Parks]
# 15                                   None                                None
# 16        [2,  National Wildlife Refuges]                                None
# 17                    [, National Forest]          [, National Historic Park]
# 18                                   None                                None
# 19        [4,  National Wildlife Refuges]               [, National Seashore]
# 20        [4,  National Wildlife Refuges]               [, National Seashore]
# 21                 [4,  National Forests]          [, National Historic Site]
# 22                                   None                                None
# 23                  [, National Seashore]                                None
# 24              [, State Wildlife Refuge]                 [, National Forest]
# 25        [9,  National Wildlife Refuges]        [, National Recreation Area]
# 26           [, National Recreation Area]                                None
# 27                  [, National Monument]          [, National Wildlife Area]
# 28                                   None                                None
# 29             [, National Historic Park]     [5,  National Wildlife Refuges]
# 30          [2,  National Historic Parks]            [3,  National Monuments]
# 31             [, National Historic Park]            [4,  National Monuments]
# 32                  [, National Memorial]       [2,  National Historic Sites]
# 33                                   None                                None
# 34                      [, National Park]                 [, National Forest]
# 35        [2,  National Recreation Areas]        [14,  Metro and City Parkss]
# 36                [14,  National Forests]               [, National Memorial]
# 37          [3,  National Historic Parks]        [, National Wildlife Refuge]
# 38                                   None                                None
# 39          [2,  National Historic Sites]     [5,  National Wildlife Refuges]
# 40        [4,  National Wildlife Refuges]                                None
# 41                    [, National Forest]          [, National Historic Site]
# 42                 [4,  National Forests]               [, National Memorial]
# 43        [2,  National Wildlife Refuges]     [4,  National Recreation Areas]
# 44                                   None                                None
# 45          [2,  National Historic Sites]       [3,  National Historic Parks]
# 46                 [7,  National Forests]       [3,  National Historic Sites]
# 47        [2,  National Recreation Areas]      [, National Park and Preserve]
# 48  [3,  State Wildlife Management Areas]           [, State Wildlife Refuge]
# 49          [, National Recreation Trail]                                None
# 50                                   None                                None
#
#                                   8                                 9   \
# 0   [10,  National Wildlife Refuges]                              None
# 1                               None                              None
# 2         [, National Historic Site]          [9,  National Monuments]
# 3              [, National Memorial]     [3,  National Historic Sites]
# 4               [9,  National Parks]           [19,  National Forests]
# 5    [4,  National Wildlife Refuges]   [2,  National Recreation Areas]
# 6                               None                              None
# 7                               None                              None
# 8           [2,  National Memorials]    [, National Historic Landmark]
# 9         [, National Historic Site]   [9,  National Wildlife Refuges]
# 10                              None                              None
# 11   [6,  National Wildlife Refuges]      [, National Recreation Area]
# 12               [, National Forest]     [2,  National Historic Sites]
# 13                 [, National Park]               [, National Forest]
# 14                              None                              None
# 15                              None                              None
# 16                              None                              None
# 17   [8,  National Wildlife Refuges]          [, Metro and City Parks]
# 18                              None                              None
# 19                              None                              None
# 20                              None                              None
# 21        [, National Historic Park]   [4,  National Wildlife Refuges]
# 22                              None                              None
# 23                              None                              None
# 24     [2,  National Historic Sites]   [5,  National Wildlife Refuges]
# 25     [, National Recreation Trail]                              None
# 26                              None                              None
# 27   [9,  National Wildlife Refuges]      [, National Recreation Area]
# 28                              None                              None
# 29      [, National Recreation Area]                              None
# 30   [3,  National Wilderness Areas]   [8,  National Wildlife Refuges]
# 31   [5,  National Wildlife Refuges]      [, National Recreation Area]
# 32   [8,  National Wildlife Refuges]          [2,  National Seashores]
# 33                              None                              None
# 34          [2,  National Memorials]     [2,  National Historic Parks]
# 35                              None                              None
# 36        [, National Historic Site]          [2,  National Monuments]
# 37      [, National Recreation Area]          [, Metro and City Parks]
# 38                              None                              None
# 39                              None                              None
# 40                              None                              None
# 41        [, National Historic Park]   [8,  National Wildlife Refuges]
# 42        [, National Historic Site]        [, National Historic Park]
# 43          [, Metro and City Parks]                              None
# 44                              None                              None
# 45          [2,  National Monuments]      [, National Wildlife Refuge]
# 46     [2,  National Historic Parks]  [17,  National Wildlife Refuges]
# 47    [2,  Army Corps of Engineerss]                              None
# 48            [2,  National Forests]   [5,  National Wildlife Refuges]
# 49                              None                              None
# 50                              None                              None
#
#                                   10                                11  \
# 0                               None                              None
# 1                               None                              None
# 2         [, National Wildlife Area]   [7,  National Wildlife Refuges]
# 3    [9,  National Wildlife Refuges]     [, National Recreation Trail]
# 4              [, National Memorial]     [3,  National Historic Sites]
# 5                               None                              None
# 6                               None                              None
# 7                               None                              None
# 8              [, National Monument]  [20,  National Wildlife Refuges]
# 9       [, National Recreation Area]             [, National Seashore]
# 10                              None                              None
# 11  [5,  National Recreation Trails]       [2,  Metro and City Parkss]
# 12   [3,  National Wildlife Refuges]                              None
# 13             [, National Memorial]        [, National Historic Park]
# 14                              None                              None
# 15                              None                              None
# 16                              None                              None
# 17                              None                              None
# 18                              None                              None
# 19                              None                              None
# 20                              None                              None
# 21                              None                              None
# 22                              None                              None
# 23                              None                              None
# 24       [3,  Metro and City Parkss]                              None
# 25                              None                              None
# 26                              None                              None
# 27     [, National Recreation Trail]                              None
# 28                              None                              None
# 29                              None                              None
# 30      [, National Recreation Area]     [, National Recreation Trail]
# 31             [, National Seashore]                              None
# 32       [, Army Corps of Engineers]                              None
# 33                              None                              None
# 34   [3,  National Wildlife Refuges]       [3,  Metro and City Parkss]
# 35                              None                              None
# 36  [16,  National Wildlife Refuges]   [2,  National Recreation Areas]
# 37                              None                              None
# 38                              None                              None
# 39                              None                              None
# 40                              None                              None
# 41                              None                              None
# 42             [, National Monument]  [10,  National Wildlife Refuges]
# 43                              None                              None
# 44                              None                              None
# 45      [, National Recreation Area]                              None
# 46   [3,  National Recreation Areas]       [5,  Metro and City Parkss]
# 47                              None                              None
# 48       [2,  Metro and City Parkss]                              None
# 49                              None                              None
# 50                              None                              None
#
#                                   12                                13  \
# 0                               None                              None
# 1                               None                              None
# 2       [, National Recreation Area]  [4,  National Recreation Trails]
# 3                               None                              None
# 4           [5,  National Monuments]  [31,  National Wildlife Refuges]
# 5                               None                              None
# 6                               None                              None
# 7                               None                              None
# 8              [, National Seashore]                              None
# 9     [2,  Army Corps of Engineerss]                              None
# 10                              None                              None
# 11                              None                              None
# 12                              None                              None
# 13      [, National Wildlife Refuge]          [, Metro and City Parks]
# 14                              None                              None
# 15                              None                              None
# 16                              None                              None
# 17                              None                              None
# 18                              None                              None
# 19                              None                              None
# 20                              None                              None
# 21                              None                              None
# 22                              None                              None
# 23                              None                              None
# 24                              None                              None
# 25                              None                              None
# 26                              None                              None
# 27                              None                              None
# 28                              None                              None
# 29                              None                              None
# 30         [, National Natural Area]          [, Metro and City Parks]
# 31                              None                              None
# 32                              None                              None
# 33                              None                              None
# 34                              None                              None
# 35                              None                              None
# 36  [3,  National Recreation Trails]                              None
# 37                              None                              None
# 38                              None                              None
# 39                              None                              None
# 40                              None                              None
# 41                              None                              None
# 42   [2,  National Recreation Areas]             [, National Seashore]
# 43                              None                              None
# 44                              None                              None
# 45                              None                              None
# 46                              None                              None
# 47                              None                              None
# 48                              None                              None
# 49                              None                              None
# 50                              None                              None
#
#                                  14                                15  \
# 0                              None                              None
# 1                              None                              None
# 2          [, Metro and City Parks]                              None
# 3                              None                              None
# 4   [3,  National Recreation Areas]  [6,  National Recreation Trails]
# 5                              None                              None
# 6                              None                              None
# 7                              None                              None
# 8                              None                              None
# 9                              None                              None
# 10                             None                              None
# 11                             None                              None
# 12                             None                              None
# 13                             None                              None
# 14                             None                              None
# 15                             None                              None
# 16                             None                              None
# 17                             None                              None
# 18                             None                              None
# 19                             None                              None
# 20                             None                              None
# 21                             None                              None
# 22                             None                              None
# 23                             None                              None
# 24                             None                              None
# 25                             None                              None
# 26                             None                              None
# 27                             None                              None
# 28                             None                              None
# 29                             None                              None
# 30                             None                              None
# 31                             None                              None
# 32                             None                              None
# 33                             None                              None
# 34                             None                              None
# 35                             None                              None
# 36                             None                              None
# 37                             None                              None
# 38                             None                              None
# 39                             None                              None
# 40                             None                              None
# 41                             None                              None
# 42                             None                              None
# 43                             None                              None
# 44                             None                              None
# 45                             None                              None
# 46                             None                              None
# 47                             None                              None
# 48                             None                              None
# 49                             None                              None
# 50                             None                              None
#
#                        16                              17  \
# 0                    None                            None
# 1                    None                            None
# 2                    None                            None
# 3                    None                            None
# 4   [, National Seashore]  [, National Park and Preserve]
# 5                    None                            None
# 6                    None                            None
# 7                    None                            None
# 8                    None                            None
# 9                    None                            None
# 10                   None                            None
# 11                   None                            None
# 12                   None                            None
# 13                   None                            None
# 14                   None                            None
# 15                   None                            None
# 16                   None                            None
# 17                   None                            None
# 18                   None                            None
# 19                   None                            None
# 20                   None                            None
# 21                   None                            None
# 22                   None                            None
# 23                   None                            None
# 24                   None                            None
# 25                   None                            None
# 26                   None                            None
# 27                   None                            None
# 28                   None                            None
# 29                   None                            None
# 30                   None                            None
# 31                   None                            None
# 32                   None                            None
# 33                   None                            None
# 34                   None                            None
# 35                   None                            None
# 36                   None                            None
# 37                   None                            None
# 38                   None                            None
# 39                   None                            None
# 40                   None                            None
# 41                   None                            None
# 42                   None                            None
# 43                   None                            None
# 44                   None                            None
# 45                   None                            None
# 46                   None                            None
# 47                   None                            None
# 48                   None                            None
# 49                   None                            None
# 50                   None                            None
#
#                           18
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4   [, Metro and City Parks]
# 5                       None
# 6                       None
# 7                       None
# 8                       None
# 9                       None
# 10                      None
# 11                      None
# 12                      None
# 13                      None
# 14                      None
# 15                      None
# 16                      None
# 17                      None
# 18                      None
# 19                      None
# 20                      None
# 21                      None
# 22                      None
# 23                      None
# 24                      None
# 25                      None
# 26                      None
# 27                      None
# 28                      None
# 29                      None
# 30                      None
# 31                      None
# 32                      None
# 33                      None
# 34                      None
# 35                      None
# 36                      None
# 37                      None
# 38                      None
# 39                      None
# 40                      None
# 41                      None
# 42                      None
# 43                      None
# 44                      None
# 45                      None
# 46                      None
# 47                      None
# 48                      None
# 49                      None
# 50                      None

# %%
parks = pd.DataFrame(df[0].tolist(), columns=['Count', 'Type'])
parks.head()
# Out:
#   Count          Type
# 0    24   State Parks
# 1     4   State Parks
# 2    16   State Parks
# 3    36   State Parks
# 4   109   State Parks

# %%
stateparks= parks.join(states)
stateparks.head()
# Out:
#   Count          Type       State State.1 State Capital Region
# 0    24   State Parks     Alabama      AL    Montgomery  South
# 1     4   State Parks      Alaska      AK        Juneau   West
# 2    16   State Parks     Arizona      AZ       Phoenix   West
# 3    36   State Parks    Arkansas      AR   Little Rock  South
# 4   109   State Parks  California      CA    Sacramento   West

# %%
stateparks.to_csv("stateparks.csv")

# %%
stateparks.to_sql('stateparks', con=engine, if)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qc/_ykx45d102d0nr51ysx4tb4h0000gn/T/ipykernel_61564/2452204006.py in <module>
# ----> 1 stateparks.to_sql('stateparks', con=engine)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1749         sql_engine = get_engine(engine)
#    1750
# -> 1751         table = self.prep_table(
#    1752             frame=frame,
#    1753             name=name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1648             dtype=dtype,
#    1649         )
# -> 1650         table.create()
#    1651         return table
#    1652
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in create(self)
#     856         if self.exists():
#     857             if self.if_exists == "fail":
# --> 858                 raise ValueError(f"Table '{self.name}' already exists.")
#     859             elif self.if_exists == "replace":
#     860                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'stateparks' already exists.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
fbi_key = 'A9mQl78dp9FhcaFIVlhZHOSMysv6mbM1yIh3gPJe'

# %%
import sqlalchemy
import scipy.stats as st
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func, desc

# %%
states_df = pd.read_csv("states.csv", encoding='utf-8')
states_df
states_df["State.1"]=states_df["State.1"].astype('string')

# %%
state_renamed = states_df.rename(columns ={"State.1":"state_abv"})
state_renamed["Crime"] = ''
state_renamed
# Out:
#              State state_abv   State Capital     Region Crime
# 0          Alabama        AL      Montgomery      South
# 1           Alaska        AK          Juneau       West
# 2          Arizona        AZ         Phoenix       West
# 3         Arkansas        AR     Little Rock      South
# 4       California        CA      Sacramento       West
# 5         Colorado        CO          Denver       West
# 6      Connecticut        CT        Hartford  Northeast
# 7         Delaware        DE           Dover  Northeast
# 8          Florida        FL     Tallahassee      South
# 9          Georgia        GA         Atlanta      South
# 10          Hawaii        HI        Honolulu       West
# 11           Idaho        ID           Boise       West
# 12        Illinois        IL     Springfield    Midwest
# 13         Indiana        IN    Indianapolis    Midwest
# 14            Iowa        IA      Des Moines    Midwest
# 15          Kansas        KS          Topeka    Midwest
# ...

# %%
StateAbbr = state_renamed['state_abv'].to_list()
StateAbbr
# Out:
# ['AL',
#  'AK',
#  'AZ',
#  'AR',
#  'CA',
#  'CO',
#  'CT',
#  'DE',
#  'FL',
#  'GA',
#  'HI',
#  'ID',
#  'IL',
#  'IN',
#  'IA',
#  'KS',
#  'KY',
#  'LA',
#  'ME',
#  'MD',
#  'MA',
#  'MI',
#  'MN',
#  'MS',
#  'MO',
#  'MT',
#  'NE',
#  'NV',
#  'NH',
#  'NJ',
#  'NM',
#  'NY',
#  'NC',
#  'ND',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'UT',
#  'VT',
#  'VA',
#  'WA',
#  'WV',
#  'WI',
#  'WY']

# %%
#offenses = [state_id, state_abbr, opulation, violent_crime, homicide, rape_legacy, rape_revised, robbery, aggravated_assault, property_crime, burglary, larceny, motor_vehicle_theft, arson]

# %%
violence = []

for state in state_renamed['state_abv']:
    base_url= f'https://api.usa.gov/crime/fbi/sapi/api/estimates/states/{state}/2020/2020?API_KEY=A9mQl78dp9FhcaFIVlhZHOSMysv6mbM1yIh3gPJe'
    
    fbi_results = requests.get(base_url).json()

    violence.append(fbi_results["results"][0]['violent_crime'])
    
state_renamed["Crime"] = violence

# %%
state_renamed
# Out:
#              State state_abv   State Capital     Region   Crime
# 0          Alabama        AL      Montgomery      South   22322
# 1           Alaska        AK          Juneau       West    6126
# 2          Arizona        AZ         Phoenix       West   35980
# 3         Arkansas        AR     Little Rock      South   20363
# 4       California        CA      Sacramento       West  174026
# 5         Colorado        CO          Denver       West   24570
# 6      Connecticut        CT        Hartford  Northeast    6459
# 7         Delaware        DE           Dover  Northeast    4262
# 8          Florida        FL     Tallahassee      South   83368
# 9          Georgia        GA         Atlanta      South   42850
# 10          Hawaii        HI        Honolulu       West    3576
# 11           Idaho        ID           Boise       West    4432
# 12        Illinois        IL     Springfield    Midwest   53612
# 13         Indiana        IN    Indianapolis    Midwest   24161
# ...

# %%
state_renamed.rename(columns ={"state_abv":"State.1"})
# Out:
#              State State.1   State Capital     Region   Crime
# 0          Alabama      AL      Montgomery      South   22322
# 1           Alaska      AK          Juneau       West    6126
# 2          Arizona      AZ         Phoenix       West   35980
# 3         Arkansas      AR     Little Rock      South   20363
# 4       California      CA      Sacramento       West  174026
# 5         Colorado      CO          Denver       West   24570
# 6      Connecticut      CT        Hartford  Northeast    6459
# 7         Delaware      DE           Dover  Northeast    4262
# 8          Florida      FL     Tallahassee      South   83368
# 9          Georgia      GA         Atlanta      South   42850
# 10          Hawaii      HI        Honolulu       West    3576
# 11           Idaho      ID           Boise       West    4432
# 12        Illinois      IL     Springfield    Midwest   53612
# 13         Indiana      IN    Indianapolis    Midwest   24161
# ...

# %%
state_renamed.to_csv('crime_data.csv')
